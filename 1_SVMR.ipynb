# %% [markdown]
# <a href="https://colab.research.google.com/github/ragunandhant/colab/blob/main/1_SVMR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Machine Learning-Regression/Assignment/insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset.drop(['charges'],axis=1)

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
X_train
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0         0           0
# 196    39  32.800         0         0           0
# 438    52  46.750         5         0           0
# 183    44  26.410         0         0           0
# 1298   33  27.455         2         1           0
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0         1           0
# 835    42  35.970         2         1           0
# 1216   40  25.080         0         1           0
# 559    19  35.530         0         1           0
# 684    33  18.500         1         0           0
#
# [936 rows x 5 columns]

# %%
X_train
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0         0           0
# 196    39  32.800         0         0           0
# 438    52  46.750         5         0           0
# 183    44  26.410         0         0           0
# 1298   33  27.455         2         1           0
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0         1           0
# 835    42  35.970         2         1           0
# 1216   40  25.080         0         1           0
# 559    19  35.530         0         1           0
# 684    33  18.500         1         0           0
#
# [936 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVR
regressor=SVR(kernel='rbf', C=10000,epsilon=1000,degree=5)
regressor.fit(X_train,y_train)
regressor.fit_status_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0

# %%
regressor.intercept_
# Out:
# array([18202.38395584])

# %%
regressor.n_support_
# Out:
# array([345], dtype=int32)

# %%
regressor.support_
# Out:
# array([  2,   5,   6,  12,  13,  15,  21,  23,  24,  25,  29,  33,  35,
#         36,  37,  39,  41,  44,  45,  58,  59,  61,  66,  68,  70,  72,
#         75,  76,  84,  87,  92,  98, 100, 105, 107, 118, 121, 123, 124,
#        125, 126, 132, 138, 142, 147, 149, 153, 160, 165, 177, 178, 181,
#        183, 185, 187, 192, 193, 199, 200, 201, 202, 203, 204, 206, 209,
#        210, 212, 213, 214, 215, 218, 220, 225, 226, 227, 233, 234, 236,
#        239, 243, 247, 251, 255, 259, 263, 267, 269, 274, 276, 285, 286,
#        287, 289, 292, 295, 299, 303, 312, 315, 317, 319, 321, 323, 331,
#        332, 334, 335, 336, 337, 343, 345, 347, 348, 353, 359, 360, 361,
#        363, 364, 365, 369, 370, 373, 376, 382, 389, 392, 395, 399, 400,
#        401, 406, 409, 410, 412, 418, 421, 424, 426, 427, 428, 429, 430,
#        436, 437, 442, 444, 445, 446, 448, 449, 452, 453, 454, 459, 462,
#        467, 470, 472, 477, 478, 481, 486, 487, 488, 489, 490, 491, 492,
# ...

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.883852527243811

# %%
from sklearn.model_selection import train_test_split, GridSearchCV




# Step 3: Define the hyperparameter grid for SVR
param_grid = {
    'kernel': ['rbf'],
    'C': [0.1, 1, 10,1000,10000],
    'epsilon': [0.01, 0.1, 0.2,1000,500,100]
}

# Step 4: Create the GridSearchCV object
grid_search = GridSearchCV(SVR(), param_grid, cv=5, scoring='r2', n_jobs=-1)

# Step 5: Perform the grid search on the training data
grid_search.fit(X_train, y_train)

grid_search.score(X_test,y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.883852527243811

# %%
grid_search.best_estimator_
# Out:
# SVR(C=10000, epsilon=1000)
